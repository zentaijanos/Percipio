# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Hashtag distributions

# %%
from IPython.display import Image

# %% [markdown]
# ## Full time period data
# ### Normal hashtag:

# %%
Image(filename='results/<UNK>.png')

# %%
Image(filename='results/Brexit.png')

# %%
Image(filename='results/EU.png')

# %%
Image(filename='results/EUref.png')

# %%
Image(filename='results/InOrOut.png')

# %%
Image(filename='results/UK.png')

# %% [markdown]
# ### Campagin slogen hastag:

# %%
Image(filename='results/VoteLeave.png')

# %%
Image(filename='results/LeaveEU.png')

# %%
Image(filename='results/StrongerIn.png')

# %% [markdown]
# ## Between June 21-29
# ### Normal hashtag:

# %%
Image(filename='results/<UNK>_juni2129.png')

# %%
Image(filename='results/Brexit_juni2129.png')

# %%
Image(filename='results/EU_juni2129.png')

# %%
Image(filename='results/EUref_juni2129.png')

# %%
Image(filename='results/InOrOut_juni2129.png')

# %%
Image(filename='results/UK_juni2129.png')

# %% [markdown]
# ### Campagin slogen hashtag:

# %%
Image(filename='results/VoteLeave_juni2129.png')

# %%
Image(filename='results/LeaveEU_juni2129.png')

# %%
Image(filename='results/StrongerIn_juni2129.png')

# %% [markdown]
# ## Between June 23-25
# ### Normal hashtag:

# %%
Image(filename='results/<UNK>_juni2325.png')

# %%
Image(filename='results/Brexit_juni2325.png')

# %%
Image(filename='results/EU_juni2325.png')

# %%
Image(filename='results/EUref_juni2325.png')

# %%
Image(filename='results/InOrOut_juni2325.png')

# %%
Image(filename='results/UK_juni2325.png')

# %% [markdown]
# ### Campagin slogen hashtag:

# %%
Image(filename='results/VoteLeave_juni2325.png')

# %%
Image(filename='results/LeaveEU_juni2325.png')

# %%
Image(filename='results/StrongerIn_juni2325.png')

# %% [markdown]
# ## Most active users:

# %%
import pandas as pd
# %matplotlib notebook
#%pylab inline

# %%
u_id_list = pd.read_csv('data/depo/u_id_sorted.dat',header=None)
user_activity = pd.DataFrame(u_id_list[0].value_counts())

# %%
#user_activity.head(10).reset_index()

# %%
mylist=['brexitmarch','Col_Connaughton','LiveEUDebate','rotenyahu','ChaseCarbon','Not found','Not found','Fight4UK','MikkiL','marie52d']

# %%
lista=pd.DataFrame(mylist,columns=['User name'])

# %%
result = pd.merge(user_activity.head(10).reset_index(),lista,left_index=True,right_index=True,how='outer')

# %%
result.columns = ['User ID', 'Count','User name']

# %%
result
# Out:
#               User ID  Count        User name
# 0  723762751596822528  73878      brexitmarch
# 1           379851447  53572  Col_Connaughton
# 2  723251650174017536  48973     LiveEUDebate
# 3  701759133654061057  45601        rotenyahu
# 4  723251262398054400  28979      ChaseCarbon
# 5          4706912477  22874        Not found
# 6            28779194  20678        Not found
# 7           328484372  20526         Fight4UK
# 8            27839828  15132           MikkiL
# 9  712736810661765120  14246         marie52d

# %%
x = result['User ID']
y = result['Count']

# %%
y_pos = np.arange(len(result['User ID']))
plt.bar(y_pos, result['Count'], align='center', alpha=0.7)
my_xticks = ['12','16','18','22','66','155','188','221','224','246']
plt.xticks(y_pos,mylist,rotation=60)
plt.grid(True)
plt.tight_layout()

# %%
data = pd.read_csv('data/ht_conv.dat',sep='\t',header=None)

# %%
#data.head()

# %%
datetime.datetime.strptime
data[1] = pd.to_datetime(data[1])
data = data.set_index(data[1])

# %%
#data.head()

# %%
#uid=723762751596822528
#data.loc[data[3] == uid].head().hist(bins=150)

# %%
# %matplotlib inline
import datetime
def uid_plot(uid,title):
    data.loc[data[3]==uid][1].hist(bins=150,color='r')
    #plt.show()
    plt.title('user name: @'+title)
    plt.xticks(rotation=45)
    plt.tight_layout()
    #plt.savefig('results/uid_'+uid+'.png')

# %%
uid_plot(723762751596822528,'brexitmarch')

# %%
uid_plot(379851447,'Col_Connaughton')

# %%
uid_plot(723251650174017536, 'LiveEUDebate')

# %%
uid_plot(701759133654061057,'rotenyahu')

# %%
uid_plot(723251262398054400,'ChaseCarbon')

# %%
uid_plot(328484372,'Fight4UK')

# %% [markdown]
# ## VoteLeave and StrongerIn
# ### Just each hashtag

# %%
def propaganda_plot(htag):
    data.loc[data[2]==htag][1].hist(bins=150,color='k')
    #plt.show()
    plt.title('#'+htag)
    plt.xticks(rotation=45)
    plt.tight_layout()
    #plt.savefig('results/uid_'+uid+'.png')

# %%
#data.head()

# %%
propaganda_plot('VoteLeave')

# %%
propaganda_plot('StrongerIn')
